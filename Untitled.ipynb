# %%
#import all required modules
# %load_ext autoreload
# %autoreload 2
from modules.xstream import Stream
from modules.xenum import StreamType
from detection.core import DLModel
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
from detection.xresult import XResult
from modules.xplot import XPlot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = YOLO('./assets/models/yolov8n.pt')

# %%
res = model('./assets/images/img1.png', classes=[0, 2])
# Out:
# image 1/1 D:\jupyter-notebook\reach_files\cv_thesis_repo\assets\images\img1.png: 384x640 4 persons, 7 cars, 53.0ms
# Speed: 3.0ms preprocess, 53.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
plt.imshow(res[0].plot())

# %%
r = XResult(res)

# %%
pred = XPlot(r)

# %%
plt.imshow(pred.plot())
# Out:
# 11
# ...
# [[     726.41      798.69        1463      1075.1]
#  [     1048.2      351.22      1491.1      594.89]
#  [     984.13      144.02      1290.3      292.93]
#  [     137.56      350.05      183.14      495.23]
#  [     1501.8      3.4762      1607.8      78.594]
#  [     76.681      240.94      394.57      399.35]
#  [     1773.4      139.92      1915.9      276.75]
#  [     285.64      368.87      353.77      522.74]
#  [     965.08      79.984      1143.3      167.69]
#  [      150.9      554.89      250.03      706.66]
#  [     1591.9      604.22      1647.7      729.55]]
# [[ 726  798 1463 1075]
#  [1048  351 1491  594]
#  [ 984  144 1290  292]
#  [ 137  350  183  495]
#  [1501    3 1607   78]
#  [  76  240  394  399]
#  [1773  139 1915  276]
#  [ 285  368  353  522]
#  [ 965   79 1143  167]
#  [ 150  554  250  706]
#  [1591  604 1647  729]]
# [[     726.41      798.69        1463      1075.1]
#  [     1048.2      351.22      1491.1      594.89]
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
model = YOLO('./assets/models/yolov8n.pt')
res = model('./assets/images/img1.png', classes=[0, 2])
# Out:
# image 1/1 D:\jupyter-notebook\reach_files\cv_thesis_repo\assets\images\img1.png: 384x640 4 persons, 7 cars, 67.0ms
# Speed: 4.0ms preprocess, 67.0ms inference, 1961.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
import numpy as np

class XResult():
    def __init__(self, results):
        self.result = results[0]

    @property
    def boxes(self):
        return self.result.boxes
        
    @property
    def img(self):
        return self.result.orig_img

    @property
    def cls(self):
        return self.boxes.cls.cpu().numpy()

    @property
    def conf(self):
        return self.boxes.conf

    @property
    def ids(self):
        return self.boxes.id.cpu().numpy().astype(int) if self.boxes.id is not None else None

    @property
    def names(self):
        return self.result.names

    @property
    def xyxy(self):
        return self.boxes.xyxy.cpu().numpy().astype(int)
    
    @property
    def xywh(self):
        return self.boxes.xywh.cpu().numpy().astype(int)

    @property
    def xcyc(self):
        xcyc = np.empty((len(self.boxes), 2), dtype=int)
        for i, row in enumerate(self.xyxy):
          x1, y1, x2, y2 = row
          xc = int((x1 + x2) / 2)
          yc = int((y1 + y2) / 2)
          xcyc[i, 0] = xc
          xcyc[i, 1] = yc
        return xcyc

# %%
import cv2
class XPlot(object):
    def __init__(self, result, bb_color = (0, 255, 255), bb_thickness=1):
        self.result = result
        self.bb_color = bb_color
        self.bb_thickness = bb_thickness
        self.text_color = (0, 255, 255)
        self.text_thickness = 2
        self.font = cv2.FONT_HERSHEY_SIMPLEX
        self.font_scale = 1
        self.center_color = (0, 255, 255)
        
    @property
    def boxes(self):
        return self.result.boxes

    @property
    def img(self):
        return self.result.img

    def plot(self):
        for idx, xbox in enumerate(self.xboxes):
            x1, y1, x2, y2 = self.result.xyxy[idx]
            x, y, w, h = self.result.xyxy[idx]
            xc, yc = self.result.xcyc[idx]
            class_id = self.result.cls[idx]
            class_name = self.result.names[class_id]
            cv2.rectangle(self.img, (x1, y1), (x2, y2), self.bb_color, thickness=self.bb_thickness, lineType=cv2.LINE_AA)
            if class_id == 0:
                cv2.rectangle(self.img, (xc-10, yc-20), (xc+130, yc+15), self.bb_color, -1)
            elif class_id == 2:
                cv2.rectangle(self.img, (xc-10, yc-20), (xc+60, yc+15), self.bb_color, -1)
            cv2.putText(self.img, f'{class_name}-{(xc, yc)}', (xc-5, yc+5), self.font, self.font_scale, self.text_color, self.text_thickness)
            time.sleep(0.010)
            cv2.circle(self.img, (xc, yc), 5, (255,0,0), -1, cv2.LINE_AA)
            print(xc, yc)
            if xbox.danger:
                print('fullfill')
                cv2.circle(self.img, (xc, yc), 15, self.center_color, -1, cv2.LINE_AA)
                # cv2.putText(self.img, f'{xbox.danger_label}', (xc-5, yc+25), self.font, self.font_scale, self.text_color, self.text_thickness)
        return self.img

# %%
plt.imshow(res[0].plot())

# %%
xres = XResult(results=res)

# %%
pred = XPlot(xres)

# %%
plt.imshow(pred.plot())
# Out:
# 11

# %%
from detection.xresult import XBoxes

# %%
xbox = XBoxes(res)

# %%
xbox.danger
# Out:
# True

# %%
from shapely.geometry import Polygon, Point

# %%
polygon = [[(928, 218), (737, 190), (435, 155), (195, 143), (30, 315), (373, 350), (740, 396), (903, 427), (929, 219)]]

# %%
Point(965, 418).within(Polygon(polygon[0]))
# Out:
# False

# %%
a = [0,0,0,1,1,1,0]
list(set(a))
# Out:
# [0, 1]

# %%
stream = Stream(stream_type = StreamType.file)
stream.set_file_location('./assets/videos/vid001.mp4')

# %%
frames = stream.extract_frames()
# Out:
# [msg]: cap loading completed.
# Extracting frames:   7%|████▍                                                        | 36/499 [00:00<00:02, 180.62it/s]
# [msg]: cap loading completed.
# [msg]: start extracting frames | total frames: 499
# Extracting frames: 100%|████████████████████████████████████████████████████████████| 499/499 [00:02<00:00, 197.82it/s]

# %%
dlmodel = DLModel()
model = dlmodel.load_model()

# %%
dlmodel.pred_frame_list(frames)

# %%
dlmodel.save_prediction('vid01.mp4')

# %%
import pickle
import cv2
import matplotlib.pyplot as plt

# %%
with open('results.pickle', 'rb') as f:
    loaded_list = pickle.load(f)

# %%
loaded_list[0]
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
class XPlot(object):
    def __init__(self, results, bb_color = (0, 255, 255), bb_thickness=1):
        self.result = results[0]
        self.bb_color = bb_color
        self.bb_thickness = bb_thickness
        self.text_color = (0, 255, 255)
        self.text_thickness = 2
        self.font = cv2.FONT_HERSHEY_SIMPLEX
        self.font_scale = 1
        
    @property
    def boxes(self):
        return self.result.boxes

    @property
    def img(self):
        return self.result.orig_img

    def plot(self):
        for box in self.boxes:
            x1, y1, x2, y2 = [int(i) for i in box.xyxy.cpu().numpy()[0]]
            class_id = int(box.cls.cpu().numpy()[0])
            class_name = self.result.names[class_id]
            cv2.rectangle(self.img, (x1, y1), (x2, y2), self.bb_color, thickness=self.bb_thickness)
            cv2.putText(self.img, class_name, (x1, y1-5), self.font, self.font_scale, self.text_color, self.text_thickness)
            return self.img

# %%
for i in loaded_list.copy():
    p = XPlot(results=i)
    pred = p.plot()
    cv2.imshow('pred', pred)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
cv2.destroyAllWindows()

# %%
plt.imshow(cv2.cvtColor(p.img, cv2.COLOR_RGB2BGR))
plt.show()

# %%
loaded_list[0][0].boxes
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 0., 2., 0., 2., 2., 0.], device='cuda:0')
# conf: tensor([0.8427, 0.8094, 0.7594, 0.6135, 0.4770, 0.4609, 0.2918, 0.2786], device='cuda:0')
# data: tensor([[7.2636e+02, 8.0046e+02, 1.4798e+03, 1.0762e+03, 8.4269e-01, 2.0000e+00],
#         [9.9043e+02, 1.4436e+02, 1.2893e+03, 2.9303e+02, 8.0942e-01, 2.0000e+00],
#         [7.8055e+02, 4.8230e+02, 8.8942e+02, 6.7737e+02, 7.5938e-01, 0.0000e+00],
#         [1.5027e+03, 5.8620e+00, 1.6091e+03, 7.9449e+01, 6.1355e-01, 2.0000e+00],
#         [1.5930e+03, 6.0368e+02, 1.6494e+03, 7.3089e+02, 4.7701e-01, 0.0000e+00],
#         [1.7736e+03, 1.4021e+02, 1.9168e+03, 2.8580e+02, 4.6094e-01, 2.0000e+00],
#         [9.6971e+02, 8.0136e+01, 1.1438e+03, 1.6745e+02, 2.9184e-01, 2.0000e+00],
#         [1.3413e+03, 4.1576e+02, 1.3634e+03, 4.6371e+02, 2.7864e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# ...

# %%
cv2.imshow('test', res)

cv2.waitKey(0)

# Close all OpenCV windows
cv2.destroyAllWindows()

# %%
import time
for i in frames:
    res = model(i, verbose=False)[0]
    plot = res.plot()
    print(plot.shape)
    cv2.imshow('test', plot)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# ...

# %%
import cv2

# Load your image
# image = cv2.imread('./assets/images/img1.jpg')
# print(image.shape)
image = frames[0]
print(image.shape)
# Display the image
cv2.imshow('Image', image)

# Wait for a key event indefinitely
cv2.waitKey(0)

# Close all OpenCV windows
cv2.destroyAllWindows()
# Out:
# (1080, 1920, 3)
